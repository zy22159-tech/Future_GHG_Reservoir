# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,normalize
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.neural_network import MLPRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
# 评估指标函数
def evaluate(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    nse = 1 - np.sum((y_true - y_pred)**2) / np.sum((y_true - np.mean(y_true))**2)
    return rmse, mae, r2, nse

# %%
def process_dataframe(df, target_column, test_size=0.1, random_state=42):
    # List of all possible CH4 columns
    carbon_columns = ['CO2_diffusive__mgCO2_m_2_h_1_',
                   'CH4_diffusive__mgCH4_m_2_h_1_', 
                   'CH4_Bubbling__mgCH4_m_2_h_1_']

    # Drop the columns that are not the target column
    filtered_df = df.drop(columns=[col for col in carbon_columns if col != target_column])
    filtered_df = filtered_df.drop(columns=['GSD_ID','Climate_zone','Reservoir_name','Impoundment_year', 'GRanD_ID','Period_of_sampling',
       'Longitude__DD_', 'Latitude__DD_','Dam_Height__m_','Catchment_area__km2_','Chl a','GHI_kWh_m2_month','PET_kg_m_2_month_1','CH4_Total_Flux_mg_m_2_h_1_',
                      'Total_Phosphorus__mg_L_1_','Sampled_Year','Source', 'Sampled_month',
                      'References', 'Ref__no', 'Final_Ref_no', 'SOC', 'Region'])
    filtered_df = filtered_df.dropna()
    # Columns to log transform
    log_transform_columns = ['Volume_million_m3', 'Reservoir_area__km2_','CH4_Bubbling__mgCH4_m_2_h_1_']

    # Apply log transformation to specified columns
    for column in log_transform_columns:
        if column in filtered_df.columns:
            filtered_df[f'log_{column}'] = np.log10(filtered_df[column]) 
            filtered_df.drop(columns=[column], inplace=True)

    # Update the target column name if it was log-transformed
    if target_column in log_transform_columns:
        target_column = f'log_{target_column}'


    X = filtered_df.drop(columns=[target_column])
    y = filtered_df[target_column]
    
    # 划分数据集
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # 数据归一化
    scaler = MinMaxScaler(feature_range=(0, 1))
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    return X_train_scaled, X_test_scaled, y_train, y_test

# %%
# 加载数据
df_raw = pd.read_csv('Data\merged_df_v2.csv')
#df_raw = pd.read_csv('Data\merged_df_modelling.csv')

# %%
def grid_search_function (param_grid, model, X_train_scaled, X_test_scaled, y_train, y_test):
    # 创建 GridSearchCV 对象
    grid_search = GridSearchCV(model, param_grid, cv=5, scoring='r2', n_jobs=1)
    # 训练模型
    grid_search.fit(X_train_scaled, y_train)

    # 输出最佳参数
    print("最佳参数: ", grid_search.best_params_)

    # 使用最佳参数创建最终模型
    best_model = grid_search.best_estimator_


    # 预测
    y_pred_train = best_model.predict(X_train_scaled)
    y_pred_test = best_model.predict(X_test_scaled)

    train_rmse, train_mae, train_r2, train_nse = evaluate(y_train, y_pred_train)
    print("Training Set")
    print(f"RMSE: {train_rmse}")
    print(f"MAE: {train_mae}")
    print(f"R^2: {train_r2}")
    print(f"NSE: {train_nse}")
    
    # 评估 BPNN 模型
    rmse, mae, r2, nse = evaluate(y_test, y_pred_test)

    print("Testing set")
    print(f"RMSE: {rmse}")
    print(f"MAE: {mae}")
    print(f"R^2: {r2}")
    print(f"NSE: {nse}")

# %%
CO2_X_train_scaled, CO2_X_test_scaled, CO2_y_train, CO2_y_test = process_dataframe(df_raw, 'CO2_diffusive__mgCO2_m_2_h_1_')
CH4_X_train_scaled, CH4_X_test_scaled, CH4_y_train, CH4_y_test = process_dataframe(df_raw, 'CH4_diffusive__mgCH4_m_2_h_1_')
ebu_CH4_X_train_scaled, ebu_CH4_X_test_scaled, ebu_CH4_y_train, ebu_CH4_y_test = process_dataframe(df_raw, 'CH4_Bubbling__mgCH4_m_2_h_1_')

# %% [markdown]
# CO2_diffusive, Random Tree

# %%
# 定义参数网格
param_grid_rf_CO2_diff = {
    'n_estimators': [180,190,200,210,220],
    'max_depth': [None, 9, 10, 11, 12],
    'min_samples_split': [15, 20, 25, 30],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True, False]
}

# %%
# 定义随机森林模型
rf = RandomForestRegressor(random_state=42)

# 使用 GridSearchCV 查找最佳参数
grid_search_rf = GridSearchCV(rf, param_grid_rf_CO2_diff, cv=5, scoring='r2')

grid_search_rf.fit(CO2_X_train_scaled, CO2_y_train)


# 使用最佳参数创建最终模型
best_rf = grid_search_rf.best_estimator_



# 在测试集上进行预测
y_pred_train = best_rf.predict(CO2_X_train_scaled)
y_pred_rf = best_rf.predict(CO2_X_test_scaled)

# 打印出每个参数组合的R^2得分
#results = grid_search_rf.cv_results_
#for mean_score, params in zip(results['mean_test_score'], results['params']):
    #print(f"Mean R^2: {mean_score:.4f} with params: {params}")

# 评估模型表现
rmse_rf, mae_rf, r2_rf, nse_rf = evaluate(CO2_y_test, y_pred_rf)

# 输出结果
print("最佳参数:", grid_search_rf.best_params_)
print(f"RMSE: {rmse_rf:.4f}")
print(f"MAE: {mae_rf:.4f}")
print(f"R^2: {r2_rf:.4f}")
print(f"NSE: {nse_rf:.4f}")

# %%
# 定义模型
xgb = XGBRegressor(random_state=42)

# 定义需要搜索的参数网格
param_grid_xgb_CO2_diff = {
    'n_estimators': [180, 190, 200, 210, 220],
    'max_depth': [7,8,9,10],
    'learning_rate': [0.001,0.01,0.1],
    'subsample': [0.3,0.4,0.5,0.6,0.7]
}

# 使用 GridSearchCV 查找最佳参数
grid_search_xgb = GridSearchCV(xgb, param_grid_xgb_CO2_diff, cv=5, scoring='r2')

grid_search_xgb.fit(CO2_X_train_scaled, CO2_y_train)

# 使用最佳参数创建最终模型
best_xgb = grid_search_xgb.best_estimator_

# 在测试集上进行预测
y_pred_train_xgb = best_xgb.predict(CO2_X_train_scaled)
y_pred_xgb = best_xgb.predict(CO2_X_test_scaled)

# 评估模型表现
rmse_xgb, mae_xgb, r2_xgb, nse_xgb = evaluate(CO2_y_test, y_pred_xgb)

# 输出结果
print("最佳参数:", grid_search_xgb.best_params_)
print(f"RMSE: {rmse_xgb:.4f}")
print(f"MAE: {mae_xgb:.4f}")
print(f"R^2: {r2_xgb:.4f}")
print(f"NSE: {nse_xgb:.4f}")
# Out:
# 最佳参数: {'learning_rate': 0.01, 'max_depth': 8, 'n_estimators': 200, 'subsample': 0.6}
# RMSE: 111.7587
# MAE: 50.8235
# R^2: 0.2354
# NSE: 0.2354

# %% [markdown]
# CH4_diffusive, Random Tree

# %%
# 定义参数网格
param_grid_rf_CH4_diff = {
    'n_estimators': [100,110,120,130],
    'max_depth': [None, 12,13,14,15],
    'min_samples_split': [1, 2, 3, 4],
    'min_samples_leaf': [1, 2, 3],
    'bootstrap': [True, False]
}

# %%
# 定义随机森林模型
rf = RandomForestRegressor(random_state=42)

# 使用 GridSearchCV 查找最佳参数
grid_search_rf = GridSearchCV(rf, param_grid_rf_CH4_diff, cv=5, n_jobs=1, scoring='r2')

grid_search_rf.fit(CH4_X_train_scaled, CH4_y_train)


# 使用最佳参数创建最终模型
best_rf = grid_search_rf.best_estimator_



# 在测试集上进行预测
y_pred_rf = best_rf.predict(CH4_X_test_scaled)

# 评估模型表现
rmse_rf, mae_rf, r2_rf, nse_rf = evaluate(CH4_y_test, y_pred_rf)

# 输出结果
print("最佳参数:", grid_search_rf.best_params_)
print(f"RMSE: {rmse_rf:.4f}")
print(f"MAE: {mae_rf:.4f}")
print(f"R^2: {r2_rf:.4f}")
print(f"NSE: {nse_rf:.4f}")
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 600 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan         nan -0.44786858 -0.4464074
#  -0.45314851 -0.44426089 -0.43601865 -0.43344529 -0.43302185 -0.43241336
#  -0.39067949 -0.38510324 -0.39439436 -0.38300147         nan         nan
#          nan         nan -0.14616429 -0.14101104 -0.12751587 -0.13647122
#  -0.14616429 -0.14101104 -0.12751587 -0.13647122 -0.14616429 -0.14101104
#  -0.12751587 -0.13647122         nan         nan         nan         nan
#  -0.13998811 -0.13163436 -0.1170742  -0.12207208 -0.13998811 -0.13163436
#  -0.1170742  -0.12207208 -0.13998811 -0.13163436 -0.1170742  -0.12207208
#          nan         nan         nan         nan -0.45384559 -0.45332747
#  -0.4610739  -0.45423747 -0.43376071 -0.4264772  -0.42321627 -0.41002163
#  -0.41092002 -0.39950662 -0.40719584 -0.39152751         nan         nan
#          nan         nan -0.13990295 -0.13512233 -0.1221387  -0.13143537
#  -0.13990295 -0.13512233 -0.1221387  -0.13143537 -0.13990295 -0.13512233
#  -0.1221387  -0.13143537         nan         nan         nan         nan
#  -0.13786497 -0.12915473 -0.11505217 -0.1203182  -0.13786497 -0.12915473
#  -0.11505217 -0.1203182  -0.13786497 -0.12915473 -0.11505217 -0.1203182
#          nan         nan         nan         nan -0.42837853 -0.42557268
#  -0.42556911 -0.4223334  -0.43836064 -0.43425305 -0.43970483 -0.43625804
#  -0.39725887 -0.38999691 -0.38718763 -0.37246845         nan         nan
#          nan         nan -0.14896775 -0.14525545 -0.12813255 -0.13603466
#  -0.14896775 -0.14525545 -0.12813255 -0.13603466 -0.14896775 -0.14525545
#  -0.12813255 -0.13603466         nan         nan         nan         nan
#  -0.14222428 -0.13307746 -0.11847858 -0.12216604 -0.14222428 -0.13307746
#  -0.11847858 -0.12216604 -0.14222428 -0.13307746 -0.11847858 -0.12216604
#          nan         nan         nan         nan -0.45765012 -0.45430497
#  -0.46001699 -0.44981763 -0.44970842 -0.44023217 -0.43914253 -0.43731672
#  -0.4021005  -0.39179104 -0.39682619 -0.38240126         nan         nan
#          nan         nan -0.14919358 -0.14325475 -0.12700562 -0.13457425
#  -0.14919358 -0.14325475 -0.12700562 -0.13457425 -0.14919358 -0.14325475
#  -0.12700562 -0.13457425         nan         nan         nan         nan
#  -0.13759279 -0.12968355 -0.11546297 -0.12065725 -0.13759279 -0.12968355
#  -0.11546297 -0.12065725 -0.13759279 -0.12968355 -0.11546297 -0.12065725
#          nan         nan         nan         nan -0.44110014 -0.44412517
#  -0.45333397 -0.44341501 -0.44347088 -0.4364737  -0.44109605 -0.42571252
#  -0.38007493 -0.37759411 -0.38658032 -0.37432662         nan         nan
#          nan         nan -0.14715381 -0.1408338  -0.12810387 -0.13623052
#  -0.14715381 -0.1408338  -0.12810387 -0.13623052 -0.14715381 -0.1408338
#  -0.12810387 -0.13623052         nan         nan         nan         nan
#  -0.13845748 -0.12997069 -0.11555218 -0.12074323 -0.13845748 -0.12997069
#  -0.11555218 -0.12074323 -0.13845748 -0.12997069 -0.11555218 -0.12074323
#          nan         nan         nan         nan -2.07883327 -2.07465139
#  -2.0759665  -2.07695052 -2.05386869 -2.05299113 -2.05505448 -2.05863062
#  -2.05260111 -2.05250092 -2.0512767  -2.05102141         nan         nan
#          nan         nan -1.22547237 -1.22873435 -1.23098739 -1.23092509
#  -1.22547237 -1.22873435 -1.23098739 -1.23092509 -1.22547237 -1.22873435
#  -1.23098739 -1.23092509         nan         nan         nan         nan
#  -0.28236374 -0.28239556 -0.28223886 -0.28241634 -0.28236374 -0.28239556
#  -0.28223886 -0.28241634 -0.28236374 -0.28239556 -0.28223886 -0.28241634
#          nan         nan         nan         nan -2.06405063 -2.06354584
#  -2.06382907 -2.06177979 -2.04782842 -2.04419005 -2.04226474 -2.0423869
#  -2.0498449  -2.04698032 -2.04685608 -2.047979           nan         nan
#          nan         nan -1.2287048  -1.23191684 -1.23563009 -1.23513666
#  -1.2287048  -1.23191684 -1.23563009 -1.23513666 -1.2287048  -1.23191684
#  -1.23563009 -1.23513666         nan         nan         nan         nan
#  -0.2820424  -0.28191912 -0.28182989 -0.28205174 -0.2820424  -0.28191912
#  -0.28182989 -0.28205174 -0.2820424  -0.28191912 -0.28182989 -0.28205174
#          nan         nan         nan         nan -2.05112625 -2.05061772
#  -2.05167913 -2.05043569 -2.05944182 -2.05946969 -2.05744308 -2.05709019
#  -2.0557142  -2.05507165 -2.05402964 -2.05321653         nan         nan
#          nan         nan -1.2229308  -1.22749054 -1.23089929 -1.23109822
#  -1.2229308  -1.22749054 -1.23089929 -1.23109822 -1.2229308  -1.22749054
#  -1.23089929 -1.23109822         nan         nan         nan         nan
#  -0.28173289 -0.28155111 -0.28153235 -0.28164426 -0.28173289 -0.28155111
#  -0.28153235 -0.28164426 -0.28173289 -0.28155111 -0.28153235 -0.28164426
#          nan         nan         nan         nan -2.05875518 -2.05916927
#  -2.05981346 -2.06025355 -2.05167199 -2.05209879 -2.04865839 -2.04840153
#  -2.05940762 -2.05999347 -2.05975937 -2.05892446         nan         nan
#          nan         nan -1.22388465 -1.22967324 -1.23156474 -1.23259676
#  -1.22388465 -1.22967324 -1.23156474 -1.23259676 -1.22388465 -1.22967324
#  -1.23156474 -1.23259676         nan         nan         nan         nan
#  -0.28258893 -0.28280281 -0.28258435 -0.28257171 -0.28258893 -0.28280281
#  -0.28258435 -0.28257171 -0.28258893 -0.28280281 -0.28258435 -0.28257171
#          nan         nan         nan         nan -2.07090794 -2.07007764
#  -2.07172048 -2.07382379 -2.04887641 -2.05117433 -2.05236518 -2.05243579
#  -2.05376364 -2.05476403 -2.05517614 -2.05570544         nan         nan
#          nan         nan -1.22266643 -1.22727407 -1.22967645 -1.2299702
#  -1.22266643 -1.22727407 -1.22967645 -1.2299702  -1.22266643 -1.22727407
#  -1.22967645 -1.2299702          nan         nan         nan         nan
#  -0.28151651 -0.28160834 -0.28181833 -0.2819543  -0.28151651 -0.28160834
#  -0.28181833 -0.2819543  -0.28151651 -0.28160834 -0.28181833 -0.2819543 ]
#   warnings.warn(
# 最佳参数: {'bootstrap': True, 'max_depth': 12, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 120}
# RMSE: 1.8623
# MAE: 0.9725
# R^2: -0.0279
# NSE: -0.0279

# %%
xgb = XGBRegressor(random_state=42)

# 定义需要搜索的参数网格
param_grid_xgb_CH4_diff = {
    'n_estimators': [50,60,70,80],
    'max_depth': [11,12,13,14],
    'learning_rate': [0.001,0.01,0.1],
    'subsample': [0.1,0.2,0.3,0.4]
}

# 使用 GridSearchCV 查找最佳参数
grid_search_CH4_xgb = GridSearchCV(xgb, param_grid_xgb_CH4_diff, cv=5, scoring='r2')

grid_search_CH4_xgb.fit(CH4_X_train_scaled, CH4_y_train)

# 使用最佳参数创建最终模型
best_CH4_xgb = grid_search_CH4_xgb.best_estimator_

# 在测试集上进行预测
CH4_y_pred_train_xgb = best_CH4_xgb.predict(CH4_X_train_scaled)
CH4_y_pred_xgb = best_CH4_xgb.predict(CH4_X_test_scaled)

# 评估模型表现
rmse_xgb, mae_xgb, r2_xgb, nse_xgb = evaluate(CH4_y_test, CH4_y_pred_xgb)

# 输出结果
print("最佳参数:", grid_search_CH4_xgb.best_params_)
print(f"RMSE: {rmse_xgb:.4f}")
print(f"MAE: {mae_xgb:.4f}")
print(f"R^2: {r2_xgb:.4f}")
print(f"NSE: {nse_xgb:.4f}")
# Out:
# 最佳参数: {'learning_rate': 0.01, 'max_depth': 13, 'n_estimators': 70, 'subsample': 0.3}
# RMSE: 1.7929
# MAE: 0.9193
# R^2: 0.0472
# NSE: 0.0472

# %% [markdown]
# CH4_Total_Flux, Random Tree

# %%
# 定义参数网格
param_grid_rf_CH4_ebu = {
    'n_estimators': [120,130,140,150],
    'max_depth': [None, 10,11,12],
    'min_samples_split': [1, 2, 3],
    'min_samples_leaf': [1, 2, 3],
    'bootstrap': [True, False]
}

# %%
# 定义随机森林模型
rf = RandomForestRegressor(random_state=42)

# 使用 GridSearchCV 查找最佳参数
grid_search_rf = GridSearchCV(rf, param_grid_rf_CH4_ebu, cv=5, n_jobs=1, scoring='r2')

grid_search_rf.fit(ebu_CH4_X_train_scaled, ebu_CH4_y_train)


# 使用最佳参数创建最终模型
best_rf = grid_search_rf.best_estimator_



# 在测试集上进行预测
y_pred_rf = best_rf.predict(ebu_CH4_X_test_scaled)

# 评估模型表现
rmse_rf, mae_rf, r2_rf, nse_rf = evaluate(ebu_CH4_y_test, y_pred_rf)

# 输出结果
print("最佳参数:", grid_search_rf.best_params_)
print(f"RMSE: {rmse_rf:.4f}")
print(f"MAE: {mae_rf:.4f}")
print(f"R^2: {r2_rf:.4f}")
print(f"NSE: {nse_rf:.4f}")
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 480 fits failed out of a total of 1440.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 480 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py", line 340, in fit
#     self._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan 0.46222358 0.46481652
#  0.46516091 0.46468866 0.4604703  0.46187416 0.46222557 0.46019919
#         nan        nan        nan        nan 0.45832525 0.46083507
#  0.46154746 0.46151531 0.45832525 0.46083507 0.46154746 0.46151531
#         nan        nan        nan        nan 0.43171842 0.43333817
#  0.43529221 0.43570226 0.43171842 0.43333817 0.43529221 0.43570226
#         nan        nan        nan        nan 0.46543935 0.46728711
#  0.46750471 0.46606855 0.46524062 0.46701975 0.46706735 0.46631246
#         nan        nan        nan        nan 0.45888377 0.45970203
#  0.46066361 0.46036538 0.45888377 0.45970203 0.46066361 0.46036538
#         nan        nan        nan        nan 0.43226134 0.4337977
#  0.43580962 0.43613544 0.43226134 0.4337977  0.43580962 0.43613544
#         nan        nan        nan        nan 0.46274946 0.46424461
#  0.46481107 0.46353452 0.46495014 0.46674238 0.46632421 0.46463754
#         nan        nan        nan        nan 0.45609136 0.45875549
#  0.45999264 0.46029372 0.45609136 0.45875549 0.45999264 0.46029372
#         nan        nan        nan        nan 0.43164465 0.43326908
#  0.43501469 0.4354741  0.43164465 0.43326908 0.43501469 0.4354741
#         nan        nan        nan        nan 0.45964522 0.46258374
#  0.46369995 0.46224952 0.46388527 0.46663215 0.46670248 0.46425649
#         nan        nan        nan        nan 0.46058621 0.46267777
#  0.4632961  0.46364146 0.46058621 0.46267777 0.4632961  0.46364146
#         nan        nan        nan        nan 0.43195487 0.43357217
#  0.43533781 0.43575262 0.43195487 0.43357217 0.43533781 0.43575262
#         nan        nan        nan        nan 0.26502343 0.26560788
#  0.26617643 0.2666021  0.26874587 0.26665232 0.26788714 0.26718965
#         nan        nan        nan        nan 0.36358121 0.36469209
#  0.36401447 0.36249748 0.36358121 0.36469209 0.36401447 0.36249748
#         nan        nan        nan        nan 0.38050603 0.38054029
#  0.38027173 0.37991345 0.38050603 0.38054029 0.38027173 0.37991345
#         nan        nan        nan        nan 0.28063181 0.27928872
#  0.27886375 0.27902056 0.2865235  0.28526811 0.28479168 0.28510708
#         nan        nan        nan        nan 0.37446737 0.37360438
#  0.37272188 0.37355908 0.37446737 0.37360438 0.37272188 0.37355908
#         nan        nan        nan        nan 0.38697414 0.38732536
#  0.38684518 0.38694014 0.38697414 0.38732536 0.38684518 0.38694014
#         nan        nan        nan        nan 0.27319566 0.27337419
#  0.27211029 0.27149325 0.27297957 0.27157744 0.27178859 0.27189188
#         nan        nan        nan        nan 0.36377362 0.3650875
#  0.3643676  0.36353826 0.36377362 0.3650875  0.3643676  0.36353826
#         nan        nan        nan        nan 0.37959342 0.3794625
#  0.37911622 0.37866438 0.37959342 0.3794625  0.37911622 0.37866438
#         nan        nan        nan        nan 0.27003563 0.27009712
#  0.27093468 0.27176432 0.27021124 0.26992282 0.27072476 0.27096499
#         nan        nan        nan        nan 0.36738148 0.36909821
#  0.36884389 0.3671854  0.36738148 0.36909821 0.36884389 0.3671854
#         nan        nan        nan        nan 0.38121086 0.38122384
#  0.38088652 0.38032703 0.38121086 0.38122384 0.38088652 0.38032703]
#   warnings.warn(
# 最佳参数: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 140}
# RMSE: 0.5698
# MAE: 0.4219
# R^2: 0.4049
# NSE: 0.4049

# %%
xgb = XGBRegressor(random_state=42)

# 定义需要搜索的参数网格
param_grid_xgb_ebu = {
    'n_estimators': [90,100,110,120],
    'max_depth': [5,6,7,8,9],
    'learning_rate': [0.01,0.1,0.2,0.3],
    'subsample': [0.1,0.2,0.3,0.4]
}

# 使用 GridSearchCV 查找最佳参数
grid_search_ebu_CH4_xgb = GridSearchCV(xgb, param_grid_xgb_ebu, cv=5, scoring='r2')

grid_search_ebu_CH4_xgb.fit(ebu_CH4_X_train_scaled, ebu_CH4_y_train)

# 使用最佳参数创建最终模型
best_ebu_CH4_xgb = grid_search_ebu_CH4_xgb.best_estimator_

# 在测试集上进行预测
ebu_CH4_y_pred_train_xgb = best_ebu_CH4_xgb.predict(ebu_CH4_X_train_scaled)
ebu_CH4_y_pred_xgb = best_ebu_CH4_xgb.predict(ebu_CH4_X_test_scaled)

# 评估模型表现
rmse_xgb, mae_xgb, r2_xgb, nse_xgb = evaluate(ebu_CH4_y_test, ebu_CH4_y_pred_xgb)

# 输出结果
print("最佳参数:", grid_search_ebu_CH4_xgb.best_params_)
print(f"RMSE: {rmse_xgb:.4f}")
print(f"MAE: {mae_xgb:.4f}")
print(f"R^2: {r2_xgb:.4f}")
print(f"NSE: {nse_xgb:.4f}")
# Out:
# 最佳参数: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 110, 'subsample': 0.3}
# RMSE: 0.6581
# MAE: 0.5160
# R^2: 0.2062
# NSE: 0.2062
